# %% [markdown]
# # 第 1 步：请运行这个 cell 的函数

# %%
# 基本模板
import datetime
from IPython.display import clear_output

# Edit contact information
def contactInfo(contact_people=['-'],contact_email=['-']):
    contac_info = ''
    for i in range(len(contact_people)):
        if contact_people[i]=='':
            contac_info = contac_info+contact_people[i]+contact_email[i]+', '
        else:
            contac_info = contac_info + 'Dr. '+contact_people[i]+' ('+contact_email[i]+'), '
        contac_info = contac_info[:-2]
    return contac_info
    pass

# Format UTC time
def getUtcDate():
    utc_time = datetime.datetime.utcnow()
    return utc_time.strftime('%Y-%m-%d %H:%M:%S')
    pass

# Edit database information
def dataBase(type_position = False,org_CN_name='-',org_EN_name='-',org_CN_country='-',org_EN_country='-',\
             direction='-',deadline='-',URL='-',\
             contact_people=['-'],contact_email=['-']):
    str = ''
    str = org_CN_name+'\n'+org_EN_name +'\n'+org_CN_country+'\n'+org_EN_country+'\n'
    contact = contactInfo(contact_people,contact_email)
    str = str + '<p>'+direction+r'; \nDeadline: '+deadline+r'; \nContact: '+contact+r'; \nURL: '+URL+'<\p>\n\n'
    if type_position == 0:
        str = str + org_CN_country+org_CN_name+'招收博士研究生'+'\n'
        str = str + org_EN_name+' in '+org_EN_country+' is recruiting for a Doctoral Student'+'\n'
    elif type_position == 1:
        str = str + org_CN_country+org_CN_name+'招收硕士研究生'+'\n'
        str = str + org_EN_name+' in '+org_EN_country+" is recruiting for a Master's student"+'\n'
    elif type_position == 2:
        str = str + org_CN_country+org_CN_name+'招收博士研究生【和/或】硕士研究生'+'\n'
        str = str + org_EN_name+' in '+org_EN_country+" is recruiting for a Doctoral student【and/or】a Master's student"+'\n'
    elif type_position == 3:
        str = str + org_CN_country+org_CN_name+'招聘博后'+'\n'
        str = str + org_EN_name+' in '+org_EN_country+" is recruiting for a PostDoc"+'\n'
    else:
        str = str + '不是招聘信息'+'\n'
        
    utc_time = getUtcDate()
    str = str + 'UTC 时间：'+utc_time+'\n'
    return str
    pass

# Edit WeChat information
def weChat(type_position=False,org_CN_country='-',org_CN_name='-',direction='-',deadline='-',\
           contact_people=['-'],contact_email=['-'],URL='-'):
    str = ''
    if type_position == 0:
        str = org_CN_country+org_CN_name+' '+direction+' 方向 PhD 机会\n\n'
    elif type_position == 1:
        str = org_CN_country+org_CN_name+' '+direction+' 方向硕士机会\n\n'
    elif type_position == 2:
        str = org_CN_country+org_CN_name+' '+direction+' 方向硕士【和/或】博士机会\n\n'
    elif type_position == 3:
        str = org_CN_country+org_CN_name+' '+direction+' 方向 PostDoc 机会\n\n'
    else:
        str = '不是招聘信息'+'\n'
    str = str + '截止日期：'+deadline+'\n\n'
    contact_info = contactInfo(contact_people,contact_email)+'\n'
    str = str + '联系人：'+contact_info+'\n'
    str = str + '详情：'+URL+'\n\n'
    str = str + 'GISphere：【???】\n\n'
    if type_position == 0:
        str = str + '标签：'+org_CN_country+'；博士机会；【???】'
    elif type_position == 1:
        str = str + '标签：'+org_CN_country+'；硕士机会；【???】'
    elif type_position == 2:
        str = str + '标签：'+org_CN_country+'；博士机会；硕士机会；【???】'
    elif type_position == 3:
        str = str + '标签：'+org_CN_country+'；博后机会；【???】'
    else:
        str = str + '标签：'+org_CN_country+'；【???】'
    return str
    pass

# Edit WhatsApp information
def whatsApp(type_position=False,org_EN_country='-',org_EN_name='-',direction='-',deadline='-',\
           contact_people=['-'],contact_email=['-'],URL='-'):
    str = 'Direction: '+direction+'\n\n'
    if type_position == 0:
        str = str + 'PhD opportunity in '+org_EN_name+'\n\n'
    elif type_position == 1:
        str = str + "Master's opportunity in "+org_EN_name+'\n\n'
    elif type_position == 2:
        str = str + "PhD 【and/or】 Master's opportunity in "+org_EN_name+'\n\n'
    elif type_position == 3:
        str = str + 'PostDoc opportunity in '+org_EN_name+'\n\n'
    else:
        str = str + '不是招聘信息'+'\n'
    str = str + 'Deadline：'+deadline+'\n\n'
    contact_info = contactInfo(contact_people,contact_email)+'\n'
    str = str + 'Contact：'+contact_info+'\n'
    str = str + 'URL：'+URL+'\n\n'
    str = str + 'GISphere：【???】\n\n'
    if type_position == 0:
        str = str + 'Tags: '+org_EN_country+'; PhD opportunity;【???】'
    elif type_position == 1:
        str = str + 'Tags: '+org_EN_country+"; Master's opportunity;【???】"
    elif type_position == 2:
        str = str + 'Tags: '+org_EN_country+"; PhD 【and/or】 Master's opportunity;【???】"
    elif type_position == 3:
        str = str + 'Tags: '+org_EN_country+'; PostDoc opportunity;【???】'
    else:
        str = str + 'Tags: '+org_EN_country+';【???】'
    return str
    pass

# %% [markdown]
# # 第 2 步：请填写下列信息
# ### 若无信息则保持模板原状

# %% [markdown]
# ##### ↓ 示例

# %%
"""
clear_output()
# 示例
# 请填写下列信息。若无信息则保持模板原状。
org_EN_name = 'University of Leeds'  # 学校或机构的【英文名称】
org_CN_name = '利兹大学'  # 学校或机构的【中文名称】
org_EN_country = 'United Kingdom'  # 学校或机构的【国家中文名称】
org_CN_country = '英国'  # 学校或机构的【国家英文名称】
direction = 'Measuring life quality from digital footprints for informed policy decision making'    # 【研究方向】或【会议/暑校主题】
deadline = '2023-02-27'     # 【申请的截止时间】


# 若有多个联系人，请在contact_people和contact_email列表中自行添加'XX'.
# 例如：
#contact_people = ['Xingjie Wei','Paul Longley']
#contact_email = ['a.r.mizen@swansea.ac.uk','p.longley@ucl.ac.uk']
contact_people = ['Xingjie Wei'] # 联系人【姓名】
contact_email = ['a.r.mizen@swansea.ac.uk']  # 联系人【邮箱】

URL = 'https://phd.leeds.ac.uk/funding/301-esrc-white-rose-dtp-studentship-measuring-life-quality-from-digital-footprints-for-informed-policy-decision-making'              # 网站链接
GIS_Info_url = ''     # GISphere 链接
"""
# Out:
# "\nclear_output()\n# 示例\n# 请填写下列信息。若无信息则保持模板原状。\norg_EN_name = 'University of Leeds'  # 学校或机构的【英文名称】\norg_CN_name = '利兹大学'  # 学校或机构的【中文名称】\norg_EN_country = 'United Kingdom'  # 学校或机构的【国家中文名称】\norg_CN_country = '英国'  # 学校或机构的【国家英文名称】\ndirection = 'Measuring life quality from digital footprints for informed policy decision making'    # 【研究方向】或【会议/暑校主题】\ndeadline = '2023-02-27'     # 【申请的截止时间】\n\n\n# 若有多个联系人，请在contact_people和contact_email列表中自行添加'XX'.\n# 例如：\n#contact_people = ['Xingjie Wei','Paul Longley']\n#contact_email = ['a.r.mizen@swansea.ac.uk','p.longley@ucl.ac.uk']\ncontact_people = ['Xingjie Wei'] # 联系人【姓名】\ncontact_email = ['a.r.mizen@swansea.ac.uk']  # 联系人【邮箱】\n\nURL = 'https://phd.leeds.ac.uk/funding/301-esrc-white-rose-dtp-studentship-measuring-life-quality-from-digital-footprints-for-informed-policy-decision-making'              # 网站链接\nGIS_Info_url = ''     # GISphere 链接\n"

# %%
"""
clear_output()
# 请填写下列信息。若无信息则保持模板原状。
org_EN_name = ''  # 学校或机构的【英文名称】
org_CN_name = ''  # 学校或机构的【中文名称】
org_EN_country = ''  # 学校或机构的【国家中文名称】
org_CN_country = ''  # 学校或机构的【国家英文名称】
direction = ''    # 【研究方向】或【会议/暑校主题】
deadline = ''     # 【申请的截止时间】


# 若有多个联系人，请在contact_people和contact_email列表中自行添加'XX'.
# 例如：
# contact_people = ['Xingjie Wei','Paul Longley']
# contact_email = ['a.r.mizen@swansea.ac.uk','p.longley@ucl.ac.uk']
contact_people = [''] # 联系人【姓名】
contact_email = ['']  # 联系人【邮箱】

URL = ''              # 网站链接
GIS_Info_url = ''     # GISphere 链接
"""

# %%
clear_output()
# 请填写下列信息。若无信息则保持模板原状。
org_EN_name = 'Lund University'  # 学校或机构的【英文名称】
org_CN_name = '隆德大学'  # 学校或机构的【中文名称】
org_EN_country = 'Sweden'  # 学校或机构的【国家中文名称】
org_CN_country = '瑞典'  # 学校或机构的【国家英文名称】
direction = 'Exploring plural values of human-nature relationships in glacierized environments'    # 【研究方向】或【会议/暑校主题】
deadline = '2023-03-01'     # 【申请的截止时间】


# 若有多个联系人，请在contact_people和contact_email列表中自行添加'XX'.
# 例如：
# contact_people = ['Xingjie Wei','Paul Longley']
# contact_email = ['a.r.mizen@swansea.ac.uk','p.longley@ucl.ac.uk']
contact_people = ['Mine Islar','Cecilia Kardum Smith'] # 联系人【姓名】
contact_email = ['mine.islar@lucsus.lu.se','cecilia.kardum_smith@lucsus.lu.se']  # 联系人【邮箱】

URL = 'https://lu.varbi.com/en/what:job/jobID:577512/type:job/where:4/apply:1'              # 网站链接
GIS_Info_url = ''     # GISphere 链接

# %%
"""clear_output()
# 请填写下列信息。若无信息则保持模板原状。
org_EN_name = 'Uppsala University'  # 学校或机构的【英文名称】
org_CN_name = '乌普萨拉大学'  # 学校或机构的【中文名称】
org_EN_country = 'Sweden'  # 学校或机构的【国家中文名称】
org_CN_country = '瑞典'  # 学校或机构的【国家英文名称】
direction = 'Natural Resources and Sustainable Development/Food Security'    # 【研究方向】或【会议/暑校主题】
deadline = '2023-02-24'     # 【申请的截止时间】


# 若有多个联系人，请在contact_people和contact_email列表中自行添加'XX'.
# 例如：
# contact_people = ['Xingjie Wei','Paul Longley']
# contact_email = ['a.r.mizen@swansea.ac.uk','p.longley@ucl.ac.uk']
contact_people = ['Madeleine Granvik'] # 联系人【姓名】
contact_email = ['madeleine.granvik@balticuniv.uu.se']  # 联系人【邮箱】

URL = 'https://www.uu.se/en/about-uu/join-us/details/?positionId=590534'              # 网站链接
GIS_Info_url = ''     # GISphere 链接"""

# %% [markdown]
# # 第 3 步：请选择与 position 相应的 cell 运行
# ### 模板 txt 将输出到指定目录（C盘受限）
# <i><b>1. PhD
# 2. Master's
# 3. PhD and/or Master's
# 4. PostDoc</b></i>

# %% [markdown]
# ##### 1. PhD position 基本模板

# %%
# PhD
# > 将名字填入下列参数
str = ' **** PHD 基本模板 ****'
str = str + '\n\n---------------- 数据库 -------------------\n'
database_info = dataBase(0,org_CN_name,org_EN_name,org_CN_country,org_EN_country,\
             direction,deadline,URL,contact_people,contact_email)
str = str + database_info

str = str + '\n\n--------------- 微信聊天群 ------------------\n'
wechat_info = weChat(0,org_CN_country,org_CN_name,direction,deadline,contact_people,contact_email,URL)

str = str + wechat_info

str = str + '\n\n--------------- WhatsApp聊天群 ------------------\n'
whatsapp_info = whatsApp(0,org_EN_country,org_EN_name,direction,deadline,\
           contact_people,contact_email,URL)

str = str + whatsapp_info

print(str)

text_file = open('E:/'+getUtcDate()[:10]+org_CN_name+'_PhD_position.txt', 'w')
n = text_file.write(str)
text_file.close()
# Out:
#  **** PHD 基本模板 ****
#
# ---------------- 数据库 -------------------
# 隆德大学
# Lund University
# 瑞典
# Sweden
# <p>Exploring plural values of human-nature relationships in glacierized environments; \nDeadline: 2023-03-01; \nContact: Dr. Mine Islar (mine.islar@lucsus.lu.se)Dr. Cecilia Kardum Smith (cecilia.kardum_smith@lucsus.lu.se); \nURL: https://lu.varbi.com/en/what:job/jobID:577512/type:job/where:4/apply:1<\p>
#
# 隆德大学招收博士研究生
# Lund University in Sweden is recruiting for a Doctoral Student
# UTC 时间：2023-02-01 17:07:40
#
#
# --------------- 微信聊天群 ------------------
# 瑞典隆德大学 Exploring plural values of human-nature relationships in glacierized environments 方向 PhD 机会
#
# 截止日期：2023-03-01
#
# 联系人：Dr. Mine Islar (mine.islar@lucsus.lu.se)Dr. Cecilia Kardum Smith (cecilia.kardum_smith@lucsus.lu.se)
#
# 详情：https://lu.varbi.com/en/what:job/jobID:577512/type:job/where:4/apply:1
#
# GISphere：【???】
#
# 标签：瑞典；博士机会；【???】
#
# --------------- WhatsApp聊天群 ------------------
# ...

# %% [markdown]
# ##### 2. Master's position 基本模板

# %%
# Master's
str = " **** Master's 基本模板 ****"
str = str + '\n\n---------------- 数据库 -------------------\n'
database_info = dataBase(1,org_CN_name,org_EN_name,org_CN_country,org_EN_country,\
             direction,deadline,URL,contact_people,contact_email)
str = str + database_info

str = str + '\n\n--------------- 微信聊天群 ------------------\n'
wechat_info = weChat(1,org_CN_country,org_CN_name,direction,deadline,contact_people,contact_email,URL)

str = str + wechat_info

str = str + '\n\n--------------- WhatsApp聊天群 ------------------\n'
whatsapp_info = whatsApp(1,org_EN_country,org_EN_name,direction,deadline,\
           contact_people,contact_email,URL)

str = str + whatsapp_info

print(str)

text_file = open('E:/'+getUtcDate()[:10]+org_CN_name+'_Master_position.txt', 'w')
n = text_file.write(str)
text_file.close()
# Out:
#  **** Master's 基本模板 ****
#
# ---------------- 数据库 -------------------
#
#
#
#
# <p>; \nDeadline: ; \nContact: ; \nURL: <\p>
#
# 招收硕士研究生
#  in  is recruiting for a Master's student
# UTC 时间：2023-01-31 22:11:12
#
#
# --------------- 微信聊天群 ------------------
#   方向硕士机会
#
# 截止日期：
#
# 联系人：
#
# 详情：
#
# GISphere：【???】
#
# 标签：；硕士机会；【???】
#
# --------------- WhatsApp聊天群 ------------------
# Direction:
#
# Master's opportunity in
#
# Deadline：
#
# Contact：
#
# URL：
#
# GISphere：【???】
#
# Tags: ; Master's opportunity;【???】

# %% [markdown]
# ##### 3. PhD 和 Master's position 基本模板

# %%
# PhD 或/和 Master's
str = " **** PhD 或 Master's 基本模板 ****"
str = str + '\n\n---------------- 数据库 -------------------\n'
database_info = dataBase(2,org_CN_name,org_EN_name,org_CN_country,org_EN_country,\
             direction,deadline,URL,contact_people,contact_email)
str = str + database_info

str = str + '\n\n--------------- 微信聊天群 ------------------\n'
wechat_info = weChat(2,org_CN_country,org_CN_name,direction,deadline,contact_people,contact_email,URL)

str = str + wechat_info

str = str + '\n\n--------------- WhatsApp聊天群 ------------------\n'
whatsapp_info = whatsApp(2,org_EN_country,org_EN_name,direction,deadline,\
           contact_people,contact_email,URL)

str = str + whatsapp_info

print(str)

text_file = open('E:/'+getUtcDate()[:10]+org_CN_name+'_PhD_Master_position.txt', 'w')
n = text_file.write(str)
text_file.close()
# Out:
#  **** PhD 或 Master's 基本模板 ****
#
# ---------------- 数据库 -------------------
#
#
#
#
# <p>; \nDeadline: ; \nContact: ; \nURL: <\p>
#
# 招收博士研究生【和/或】硕士研究生
#  in  is recruiting for a Doctoral student【and/or】a Master's student
# UTC 时间：2023-01-31 22:11:12
#
#
# --------------- 微信聊天群 ------------------
#   方向硕士【和/或】博士机会
#
# 截止日期：
#
# 联系人：
#
# 详情：
#
# GISphere：【???】
#
# 标签：；博士机会；硕士机会；【???】
#
# --------------- WhatsApp聊天群 ------------------
# Direction:
#
# PhD 【and/or】 Master's opportunity in
#
# Deadline：
#
# Contact：
#
# URL：
#
# GISphere：【???】
#
# Tags: ; PhD 【and/or】 Master's opportunity;【???】

# %% [markdown]
# ##### 4. PostDoc position 基本模板

# %%
# 博后
str = " **** PostDoc 基本模板 ****"
str = str + '\n\n---------------- 数据库 -------------------\n'
database_info = dataBase(3,org_CN_name,org_EN_name,org_CN_country,org_EN_country,\
             direction,deadline,URL,contact_people,contact_email)
str = str + database_info

str = str + '\n\n--------------- 微信聊天群 ------------------\n'
wechat_info = weChat(3,org_CN_country,org_CN_name,direction,deadline,contact_people,contact_email,URL)

str = str + wechat_info

str = str + '\n\n--------------- WhatsApp聊天群 ------------------\n'
whatsapp_info = whatsApp(3,org_EN_country,org_EN_name,direction,deadline,\
           contact_people,contact_email,URL)

str = str + whatsapp_info

print(str)

text_file = open('E:/'+getUtcDate()[:10]+org_CN_name+'_PostDoc.txt', 'w')
n = text_file.write(str)
text_file.close()
# Out:
#  **** PostDoc 基本模板 ****
#
# ---------------- 数据库 -------------------
#
#
#
#
# <p>; \nDeadline: ; \nContact: ; \nURL: <\p>
#
# 招聘博后
#  in  is recruiting for a PostDoc
# UTC 时间：2023-01-31 22:11:12
#
#
# --------------- 微信聊天群 ------------------
#   方向 PostDoc 机会
#
# 截止日期：
#
# 联系人：
#
# 详情：
#
# GISphere：【???】
#
# 标签：；博后机会；【???】
#
# --------------- WhatsApp聊天群 ------------------
# Direction:
#
# PostDoc opportunity in
#
# Deadline：
#
# Contact：
#
# URL：
#
# GISphere：【???】
#
# Tags: ; PostDoc opportunity;【???】
